# %% [markdown]
# ## [Finbee.lt  - p2p lending platform dataset.](https://www.finbee.lt/)
#
# Will build 2 models:
#
# ### MODEL 1
# Predict: Client Credit Score
#
# ### MODEL 2
# #### Assuming starting stage when we are deciding to invest or not.
#
# Predict: If Client will fail on the loan (Default)
#
# Predict Confidence: Default confidence (Probability client will default)

# %% [markdown]
# ### Importing needed modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %% [markdown]
# ### Reading file

# %%
data_xls = pd.read_excel('loans.xlsx', index_col=None)
data_xls.to_csv('loans.csv', encoding='utf-8', index=False)
df = pd.read_csv('loans.csv')
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Exploring data
#
#
# **listing_id**	Unikalus numeris, kuris suteikiamas kiekvienai paskolai.
#
# **creation_date**	Paskolos paraiškos pateikimo data.
#
# **loan_paid_date**	Paskolos išmokėjimo data.
#
# **first_installement_date**	Pirmos mėnesinės įmokos data.
#
# **loan_paid_status**	Paskolos išmokėjimo statusas (1 – paskola išmokėta, 0 – paskola dar neišmokėta).
#
# **confirm_status**	Paskolos statusas (1 – paskolos gavėjas priėmė paskolos pasiūlymą, 3 – paskola pilnai grąžinta).
#
# **username**	Paskolos gavėjo vartotojo vardas.
#
# **listing_title**	Unikalus paskolos pavadinimas.
#
# **listing_category**	Paskolos paskirtis.
#
# **credit_score**	Paskolos gavėjui suteiktas kredito rizikos balas.
#
# **job_loss_insurance**	Paskolos gavėjui netekus darbo ne savo noru ADB „Gjensidige“ mokės paskolos įmokas iki 6 mėn. (1 – galioja draudimas nuo priverstinio nedarbo, 0 – draudimas nuo priverstinio nedarbo negalioja).
#
# **loan_amount**	Paskolos suma.
#
# **loan_period**	Paskolos terminas mėnesiniais.
#
# **effective_rate**	Paskolos palūkanų norma, kurią paskolos gavėjas moka investuotojams.
#
# **preferred_rate**	Pageidaujama paskolos gavėjo palūkanų norma.
#
# **amount_outstanding**	Likusi negrąžinta paskolos dalis šiai dienai.
#
# **monthly_installment**	Mėnesinė paskolos įmoka.
#
# **principal_repaid**	Grąžinta paskolos dalis.
#
# **interest_paid**	Paskolos gavėjo sumokėtų palūkanų suma.
#
# **arrears**	Visų vėluojančių paskolos įmokų suma.
#
# **loan_status**	Paskolos būsena (ok – nėra vėluojančių įmokų, late – praleista viena paskolos įmoka, arrears – praleistos dvi
#
# paskolos įmokos, default – praleistos trys ir daugiau paskolos įmokos).
#
# **type**	Paskolos tipas (B – paskola sufinansuota aukcione).
#
# **gender**	Paskolos gavėjo lytis.
#
# **post_town**	Miestas, kuriame gyvena paskolos gavėjas.
#
# **age**	Paskolos gavėjo amžius.
#
# **education**	Paskolos gavėjo išsilavinimas.
#
# **employment_status**	Paskolos gavėjo darbo sutarties tipas paskolos išdavimo momentu.
#
# **occupation**	Paskolos gavėjo užimamos pareigos paskolos išdavimo momentu.
#
# **employ_how_long**	Paskolos gavėjo darbo trukmė mėnesiais dabartinėje darbovietėje.
#
# **years_working_in_total**	Paskolos gavėjo darbo stažas metais.
#
# **dependants**	Nepilnamečių vaikų/išlaikytinių skaičius.
#
# **marital_status**	Paskolos gavėjo vedybininis statusas.
#
# **credit_check_date**	Paskolos gavėjo mokumo vertinimo data.
#
# **monthly_income**	Paskolos gavėjo namų ūkio pajamos, kurias jis gavo paskolos suteikimo metu. Jeigu paskolos gavėjas nėra susituokęs, tuomet namų ūkio pajamas sudaro tik jo vieno pajamos.
#
# **monthly_expenses**	Paskolos gavėjo namų ūkio mokamos kitų paskolų įmokos. Jeigu paskolos gavėjas nėra susituokęs, tuomet namų ūkio paskolų įmokas sudaro tik jo vieno paskolų įmokos.
#
# **available_income**	Grynosios pajamos apskaičiuojamos pagal formulę: namų ūkio mėnesio pajamos – namų ūkio turimų kitų paskolų įmokos.
#
# **dti**	Visų paskolų įmokų ir pajamų santykis apskaičiuojamas pagal formulę: namų ūkio turimų ir naujų paskolų mėnesinės įmokos / namų ūkio grynosios mėnesio pajamos.
#
# **outstanding_debts**	Esama nepadengta skola bet kuriam iš kreditorių, komunalinių, telekomunikacinių paslaugų tiekėjų ir pan., apie kurią buvo informuotas kreditų biuras.
#
# **last_debt_date**	Data, kada buvo registruota paskutinė skola bet kuriam iš kreditorių, komunalinių, telekomunikacinių paslaugų tiekėjų ir pan., apie kurią buvo informuotas kreditų biuras.

# %%
df.head()
# Out:
#    listing_id creation_date loan_paid_date first_installement_date  \
# 0       32692    2019-09-04     2019-09-05              2019-10-05
# 1       32691    2019-09-04     2019-09-05              2019-10-05
# 2       32687    2019-09-04     2019-09-05              2019-10-05
# 3       32674    2019-09-04     2019-09-04              2019-10-04
# 4       32666    2019-09-04     2019-09-05              2019-10-05
#
#    loan_paid_status  confirm_status    username        listing_title  \
# 0                 1               1  Raimonda98  "32692-Automobiliui
# 1                 1               1        bkar    "32691-Vartojimui
# 2                 1               1    vl771013    "32687-Vartojimui
# 3                 1               1    karturas    "32674-Vartojimui
# 4                 1               1   RasaMeska    "32666-Vartojimui
#
#   listing_category credit_score  job_loss_insurance  loan_amount  loan_period  \
# 0              Car            D                   0         3305           36
# 1   Other Purposes            D                   0         1900           36
# 2   Other Purposes            C                   0          665           12
# 3   Other Purposes            B                   0         1040           12
# 4   Other Purposes            B                   0         2830           24
#
#    effective_rate  preferred_rate  amount_outstanding  monthly_installment  \
# 0            0.26            0.26              3305.0               150.63
# 1            0.26            0.26              1900.0                86.59
# 2            0.19            0.19               665.0                63.79
# 3            0.13            0.13              1040.0                96.26
# 4            0.13            0.13              2830.0               143.81
#
#    principal_repaid  interest_paid  arrears loan_status type  gender  \
# 0               0.0            0.0      0.0          ok   FR  Female
# 1               0.0            0.0      0.0          ok   FR    Male
# 2               0.0            0.0      0.0          ok   FR  Female
# 3               0.0            0.0      0.0          ok   FR    Male
# 4               0.0            0.0      0.0          ok   FR  Female
#
#      post_town  age             education employment_status  \
# 0    Prienų r.   21  Vocational education          Employed
# 1  Joniškio r.   25  Vocational education          Employed
# 2      Vilnius   41              Graduate          Employed
# 3      Vilnius   26           High school          Employed
# 4    Panevėžys   33         Post graduate          Employed
#
#                              occupation employ_how_long  \
# 0        Rušiuotojas / Sorting operator               6
# 1                 Mechanikas / Mechanic               3
# 2                 Vadybininkė / Manager              60
# 3                  Vairuotojas / Driver              36
# 4  Socialinė darbuotoja / Social worker              15
#
#   years_working_in_total  dependants marital_status    credit_check_date  \
# 0                      3           0         Single  2019-09-04 00:00:00
# 1                      4           0         Single  2019-09-04 00:00:00
# 2                      6           1        Married  2019-09-04 00:00:00
# 3                      7           1        Married  2019-09-04 00:00:00
# 4                      3           2        Married  2019-09-04 00:00:00
#
#    monthly_income  monthly_expenses  available_income     dti  \
# 0             503                 0               503  0.2995
# 1             345                17               328  0.3003
# 2            1060               197               863  0.2460
# 3             484                 0               484  0.1989
# 4             849                21               828  0.1941
#
#    outstanding_debts       last_debt_date
# 0                  0                    -
# 1                  0  2018-01-04 00:00:00
# 2                  0  2016-11-30 00:00:00
# 3                  0                    -
# 4                  0                    -

# %%
#dataset size
df.shape
# Out:
# (9014, 39)

# %%
#Remove rows with missing values
df.isnull().sum()
df = df.dropna()

# %% [markdown]
# ### Features selection
# Based on dataset we see that only following feature may be of value for models:
# 1. listing_category
# 2. loan_amount
# 3. loan_period
# 4. effective_rate
# 5. monthly_installment
# 6. gender
# 7. post_town
# 8. age
# 9. education
# 10. employment_status
# 11. occupation **Dont use** - too many unique
# 12. employ_how_long
# 13. years_working_in_total **Don't use** - corrupted, wrong collection
# 14. dependants
# 15. marital_status
# 16. monthly_income
# 17. monthly_expenses **Don't use** - more than 50% of borrowers declare less than 100EUr/month expenses
# 18. available_income
# 19. dti
# 20. outstanding_debts **Don't use** - no data is collected, most are 0

# %% [markdown]
# ### Prediction target 1

# %%
#Prediction target 1
df['credit_score'].unique()
# Out:
# array(['D', 'C', 'B', 'A', 'A*'], dtype=object)

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x='credit_score',data=df,order=df['credit_score'].value_counts().index);
ax.set_xticklabels(ax.get_xticklabels(),  fontsize=15);
ax.set_title("Credit score of loan takers (kredito rizikos balas)", fontsize=20)


for i in ax.patches:
    ax.text(i.get_x()+0.2, i.get_height(), \
            str(round((i.get_height()),)), fontsize=15, color='black')

# %% [markdown]
# ### Exploratory analysis

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x='listing_category',data=df,order=df['listing_category'].value_counts().index);
ax.set_xticklabels(ax.get_xticklabels(),  fontsize=15);
ax.set_title("listing_category (Loan purpose)", fontsize=20)


for i in ax.patches:
    ax.text(i.get_x()+0.2, i.get_height(), \
            str(round((i.get_height()),)), fontsize=15, color='black')

# %%
plt.figure(figsize=(15,20))
plt.subplot(4,1,1)
ax = sns.violinplot(x='loan_amount', data=df,) 
ax.set_title('Loan amount in EUR range', fontsize=20)

plt.figure(figsize=(15,20))
plt.subplot(4,1,2)
ax2 = sns.violinplot(x='loan_period', data=df,) 
ax2.set_title('Loan period range in months', fontsize=20)

plt.figure(figsize=(15,20))
plt.subplot(4,1,3)
ax = sns.violinplot(x='effective_rate', data=df,) 
ax.set_title('Loan rate %', fontsize=20)

plt.figure(figsize=(15,20))
plt.subplot(4,1,4)
ax = sns.violinplot(x='monthly_installment', data=df[df['monthly_installment'] < 1000], showfliers=False) 
ax.set_title('Monthly payment size in Eur', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Monthly payment size in Eur')

# %%
plt.figure(figsize=(20,20))
plt.subplot(2,1,1)
df['gender'].value_counts().plot.pie(autopct='%.2f', fontsize=15).set_title("Burrowers by Genders ", fontsize=18 )


plt.figure(figsize=(20,20))
plt.subplot(2,1,2)
df.groupby('gender').age.plot(kind='kde')
plt.title('Gender by age',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Gender by age')

# %%
plt.figure(figsize=(20,10))
df['age'].plot.hist()
plt.title('Burrowers age histogram', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Burrowers age histogram')

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x='education',data=df,order=df['education'].value_counts().index);
ax.set_xticklabels(ax.get_xticklabels(),  fontsize=15);
ax.set_title("Education", fontsize=20)


for i in ax.patches:
    ax.text(i.get_x()+0.2, i.get_height(), \
            str(round((i.get_height()),)), fontsize=15, color='black')

# %%
#occupation - seems to have too mane unique values - not need
len(df['occupation'].unique())
# Out:
# 1884

# %%
#employ_how_long - Remove words
df.employ_how_long.unique()
# Out:
# array(['6', '3', '60', '36', '15', '24', '72 or more', '18', '12', '48',
#        '9'], dtype=object)

# %%
df['employ_how_long'] = df['employ_how_long'].astype(str).apply(lambda x: x.strip('or more'))
df.employ_how_long= df.employ_how_long.astype(int)
df.employ_how_long.unique()
# Out:
# array([ 6,  3, 60, 36, 15, 24, 72, 18, 12, 48,  9], dtype=int64)

# %%
plt.figure(figsize=(20,10))
df['employ_how_long'].plot.hist()
plt.title('Employed months at current work', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Employed months at current work')

# %%
df.years_working_in_total.unique()
# Out:
# array(['3', '4', '6', '7', '19', '9', '10', '20', '15', '30', '5', '13',
#        '8', '21', '14', '25', '26', '18', '16', '1', '38', '29', '24',
#        '28', '22', '40', '2', '35', '11', '41', '12', '23', '33', '3.5',
#        '27', '17', '34', '39', '36', '43', '45', '32', '31', '37', '0.3',
#        '0.4', '0.5', '1.5', '42', '44', '3,5', '1.8701', '1,5', '0',
#        '20m', '16 metu', '5.5', '2.5', '0,4', '0.6', '1.3', '1.6',
#        '1 metai', '2, 4', '2m', '5 metai', '0.7', '0.8', '7.5', '47',
#        '1.2', '0,6', '0,3', '2,5', '1.8', '4.5', '0.9', '8 men', '1.6m',
#        '46', '5 mėnesiai', '0,8', '4men', 'virs 10', '2016 08 04',
#        '1metai', '10 metų', '20 metu', '9m', '1m', '20 metų', '1.5 m',
#        '4 metai', '3-4', '2metai', '3 metai', '25+', 'apie 10 m.',
#        '6 metai', '17m.'], dtype=object)

# %%
df.years_working_in_total = df.years_working_in_total.str.replace('[^0-9]', '')
df.years_working_in_total = df.years_working_in_total.astype(int)

# %%
df[df.years_working_in_total > df.age].shape
# Out:
# (30, 39)

# %%
#some workers are working more years than they are aged. Seems this column may be corrupted
df[df.years_working_in_total < df.age].years_working_in_total.hist()

# %%
#Dont use - years_working_in_total - may be corrupted
df[df.years_working_in_total > 30].age.hist()

# %%
df.dependants.hist(figsize = (15,5))

# %%
df.marital_status.hist(figsize = (15,5))

# %%
plt.figure(figsize=(15,20))
plt.subplot(4,1,1)
ax = sns.violinplot(x='monthly_income', data=df,) 
ax.set_title('monthly_income EUR/Month', fontsize=20)

plt.figure(figsize=(15,20))
plt.subplot(4,1,2)
ax = sns.violinplot(x='monthly_expenses', data=df,) 
ax.set_title('monthly_expenses EUR/Month', fontsize=20)

plt.figure(figsize=(15,20))
plt.subplot(4,1,3)
ax = sns.violinplot(x='available_income', data=df,) 
ax.set_title('available_income EUR/Month', fontsize=20)

plt.figure(figsize=(15,20))
plt.subplot(4,1,3)
ax = sns.violinplot(x='dti', data=df,) 
ax.set_title('Debt to Income ration', fontsize=20)

plt.figure(figsize=(15,20))
plt.subplot(4,1,4)
ax = sns.violinplot(x='outstanding_debts', data=df,) 
ax.set_title('outstanding_debts', fontsize=20)
# Out:
# Text(0.5, 1.0, 'outstanding_debts')

# %%
#Drop monthly_expenses - becuase it seems suspicious that more than 50% of people declare ti have expenses less than 100$
df[df.monthly_expenses < 100].head()
# Out:
#    listing_id creation_date loan_paid_date first_installement_date  \
# 0       32692    2019-09-04     2019-09-05              2019-10-05
# 1       32691    2019-09-04     2019-09-05              2019-10-05
# 3       32674    2019-09-04     2019-09-04              2019-10-04
# 4       32666    2019-09-04     2019-09-05              2019-10-05
# 5       32638    2019-09-03     2019-09-04              2019-10-04
#
#    loan_paid_status  confirm_status    username        listing_title  \
# 0                 1               1  Raimonda98  "32692-Automobiliui
# 1                 1               1        bkar    "32691-Vartojimui
# 3                 1               1    karturas    "32674-Vartojimui
# 4                 1               1   RasaMeska    "32666-Vartojimui
# 5                 1               1      Nina61    "32638-Vartojimui
#
#   listing_category credit_score  job_loss_insurance  loan_amount  loan_period  \
# 0              Car            D                   0         3305           36
# 1   Other Purposes            D                   0         1900           36
# 3   Other Purposes            B                   0         1040           12
# 4   Other Purposes            B                   0         2830           24
# 5   Other Purposes            C                   0         2750           36
#
#    effective_rate  preferred_rate  amount_outstanding  monthly_installment  \
# 0            0.26            0.26              3305.0               150.63
# 1            0.26            0.26              1900.0                86.59
# 3            0.13            0.13              1040.0                96.26
# 4            0.13            0.13              2830.0               143.81
# 5            0.21            0.21              2750.0               114.94
#
#    principal_repaid  interest_paid  arrears loan_status type  gender  \
# 0               0.0            0.0      0.0          ok   FR  Female
# 1               0.0            0.0      0.0          ok   FR    Male
# 3               0.0            0.0      0.0          ok   FR    Male
# 4               0.0            0.0      0.0          ok   FR  Female
# 5               0.0            0.0      0.0          ok   FR  Female
#
#      post_town  age             education employment_status  \
# 0    Prienų r.   21  Vocational education          Employed
# 1  Joniškio r.   25  Vocational education          Employed
# 3      Vilnius   26           High school          Employed
# 4    Panevėžys   33         Post graduate          Employed
# 5    Skuodo r.   57           High school          Employed
#
#                                 occupation employ_how_long  \
# 0           Rušiuotojas / Sorting operator               6
# 1                    Mechanikas / Mechanic               3
# 3                     Vairuotojas / Driver              36
# 4     Socialinė darbuotoja / Social worker              15
# 5  Pagalbinė darbuotoja / Assistant worker              24
#
#    years_working_in_total  dependants marital_status    credit_check_date  \
# 0                       3           0         Single  2019-09-04 00:00:00
# 1                       4           0         Single  2019-09-04 00:00:00
# 3                       7           1        Married  2019-09-04 00:00:00
# 4                       3           2        Married  2019-09-04 00:00:00
# 5                      19           0       Divorced  2019-09-03 00:00:00
#
#    monthly_income  monthly_expenses  available_income     dti  \
# 0             503                 0               503  0.2995
# 1             345                17               328  0.3003
# 3             484                 0               484  0.1989
# 4             849                21               828  0.1941
# 5             581                26               555  0.2426
#
#    outstanding_debts       last_debt_date
# 0                  0                    -
# 1                  0  2018-01-04 00:00:00
# 3                  0                    -
# 4                  0                    -
# 5                  0                    -

# %%
plt.figure(figsize=(20,20))
plt.subplot(2,1,2)
df.groupby('loan_status').age.plot(kind='kde')
plt.title('loan_status',fontsize=20)
# Out:
# Text(0.5, 1.0, 'loan_status')

# %%
#prediction target 2
df['loan_status'].unique()
# Out:
# array(['ok', 'late', 'arrears', 'default'], dtype=object)

# %%
### How many have missing values? What to do?

# %% [markdown]
# #questions:
# - listing purpose? (listing category)
# - credit score by users? credit_score
# - amounts burrowed? loan_amount
# - loan periods?
# - laon rates ? effective_rate
# - monthly payments? monthly_installment
# - loan status, ok or default?? loan_status
# - loans by gender?
# - loans by cities?
# - loans by age?
# - loans by education?
# - loans by employment?
# - loan takers dependents, children?
# - loan takers marital status?
# - laon takers monthly income?
# - Monthly income vs amount requested?
# - monthly expenses? available income?
# - dti - debt to income rations?
# - currently outstanding debts? (Some peopel ask to refinance, but debts shown 0?)
# - who are defaultings lenders?
# - who are good lenders?
# - ML to predict default or not?
# - When loan has been given out? is it still to be paid?
# - How quickly loans gave been granted?
# - % of loans receiving funding?

# %% [markdown]
# ### Loan amount range & Loan period range

# %%
plt.figure(figsize=(20,10))
#sns.countplot(cities)
ax = sns.countplot(x='monthly_installment',data=df,order=df['monthly_installment'].index);
ax.set_xticklabels(ax.get_xticklabels(), fontsize=0);
# Out:
# Error in callback <function flush_figures at 0x0000004FC5086C18> (for post_execute):
# -----------------------------------------------------------------------
# KeyboardInterrupt                     Traceback (most recent call last)
# c:\users\val\appdata\local\programs\python\python37\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# c:\users\val\appdata\local\programs\python\python37\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# c:\users\val\appdata\local\programs\python\python37\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# c:\users\val\appdata\local\programs\python\python37\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <c:\users\val\appdata\local\programs\python\python37\lib\site-packages\decorator.py:decorator-gen-9> in __call__(self, obj)
#
# c:\users\val\appdata\local\programs\python\python37\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# c:\users\val\appdata\local\programs\python\python37\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\users\val\appdata\local\programs\python\python37\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# c:\users\val\appdata\local\programs\python\python37\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# c:\users\val\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2059                     bbox_inches = self.figure.get_tightbbox(renderer,
# -> 2060                             bbox_extra_artists=bbox_artists)
#    2061                     pad = kwargs.pop("pad_inches", None)
#    2062                     if pad is None:
#
# c:\users\val\appdata\local\programs\python\python37\lib\site-packages\matplotlib\figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2365
#    2366         for a in artists:
# -> 2367             bbox = a.get_tightbbox(renderer)
#    2368             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2369                 bb.append(bbox)
#
# c:\users\val\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4361                 bb.append(bb_yaxis)
#    4362
# -> 4363         self._update_title_position(renderer)
#    4364         axbbox = self.get_window_extent(renderer)
#    4365         bb.append(axbbox)
#
# c:\users\val\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_base.py in _update_title_position(self, renderer)
#    2547                     if (ax.xaxis.get_label_position() == 'top' or
#    2548                             ax.xaxis.get_ticks_position() in choices):
# -> 2549                         bb = ax.xaxis.get_tightbbox(renderer)
#    2550                     else:
#    2551                         bb = ax.get_window_extent(renderer)
#
# c:\users\val\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer)
#    1166         # go back to just this axis's tick labels
#    1167         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(
# -> 1168                     ticks_to_draw, renderer)
#    1169
#    1170         self._update_offset_text_position(ticklabelBoxes, ticklabelBoxes2)
#
# c:\users\val\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1148         """Return lists of bboxes for ticks' label1's and label2's."""
#    1149         return ([tick.label1.get_window_extent(renderer)
# -> 1150                  for tick in ticks if tick.label1.get_visible()],
#    1151                 [tick.label2.get_window_extent(renderer)
#    1152                  for tick in ticks if tick.label2.get_visible()])
#
# c:\users\val\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axis.py in <listcomp>(.0)
#    1148         """Return lists of bboxes for ticks' label1's and label2's."""
#    1149         return ([tick.label1.get_window_extent(renderer)
# -> 1150                  for tick in ticks if tick.label1.get_visible()],
#    1151                 [tick.label2.get_window_extent(renderer)
#    1152                  for tick in ticks if tick.label2.get_visible()])
#
# c:\users\val\appdata\local\programs\python\python37\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     890         bbox, info, descent = self._get_layout(self._renderer)
#     891         x, y = self.get_unitless_position()
# --> 892         x, y = self.get_transform().transform_point((x, y))
#     893         bbox = bbox.translated(x, y)
#     894         if dpi is not None:
#
# c:\users\val\appdata\local\programs\python\python37\lib\site-packages\matplotlib\transforms.py in transform_point(self, point)
#    1479         if len(point) != self.input_dims:
#    1480             raise ValueError("The length of 'point' must be 'self.input_dims'")
# -> 1481         return self.transform(np.asarray([point]))[0]
#    1482
#    1483     def transform_path(self, path):
#
# c:\users\val\appdata\local\programs\python\python37\lib\site-packages\matplotlib\transforms.py in transform(self, values)
#    1392
#    1393         # Transform the values
# -> 1394         res = self.transform_affine(self.transform_non_affine(values))
#    1395
#    1396         # Convert the result back to the shape of the input values.
#
# c:\users\val\appdata\local\programs\python\python37\lib\site-packages\matplotlib\transforms.py in transform_affine(self, points)
#    2371     def transform_affine(self, points):
#    2372         # docstring inherited
# -> 2373         return self.get_affine().transform(points)
#    2374
#    2375     def transform_non_affine(self, points):
#
# c:\users\val\appdata\local\programs\python\python37\lib\site-packages\matplotlib\transforms.py in get_affine(self)
#    2399         else:
#    2400             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
# -> 2401                                 self._a.get_affine().get_matrix()))
#    2402
#    2403     def inverted(self):
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Loan status - % of good and bad loans

# %%
plt.figure(figsize=(20,10))
df['loan_status'].value_counts().plot.pie(autopct='%.2f', fontsize=15).set_title("Loan status Default or ok", fontsize=18 )
# Out:
# Text(0.5, 1.0, 'Loan status Default or ok')

# %%
target = 'credit_score'
features = ['loan_amount','loan_period','effective_rate','monthly_installment','gender',
            'age','education','employment_status','employ_how_long',
            'years_working_in_total','marital_status','monthly_income',
            'available_income','dti',]

# %%
df.head()
# Out:
#    listing_id creation_date loan_paid_date first_installement_date  \
# 0       32692    2019-09-04     2019-09-05              2019-10-05
# 1       32691    2019-09-04     2019-09-05              2019-10-05
# 2       32687    2019-09-04     2019-09-05              2019-10-05
# 3       32674    2019-09-04     2019-09-04              2019-10-04
# 4       32666    2019-09-04     2019-09-05              2019-10-05
#
#    loan_paid_status  confirm_status    username        listing_title  \
# 0                 1               1  Raimonda98  "32692-Automobiliui
# 1                 1               1        bkar    "32691-Vartojimui
# 2                 1               1    vl771013    "32687-Vartojimui
# 3                 1               1    karturas    "32674-Vartojimui
# 4                 1               1   RasaMeska    "32666-Vartojimui
#
#   listing_category credit_score  job_loss_insurance  loan_amount  loan_period  \
# 0              Car            D                   0       3305.0         36.0
# 1   Other Purposes            D                   0       1900.0         36.0
# 2   Other Purposes            C                   0        665.0         12.0
# 3   Other Purposes            B                   0       1040.0         12.0
# 4   Other Purposes            B                   0       2830.0         24.0
#
#    effective_rate  preferred_rate  amount_outstanding  monthly_installment  \
# 0            0.26            0.26              3305.0               150.63
# 1            0.26            0.26              1900.0                86.59
# 2            0.19            0.19               665.0                63.79
# 3            0.13            0.13              1040.0                96.26
# 4            0.13            0.13              2830.0               143.81
#
#    principal_repaid  interest_paid  arrears loan_status type  gender  \
# 0               0.0            0.0      0.0          ok   FR  Female
# 1               0.0            0.0      0.0          ok   FR    Male
# 2               0.0            0.0      0.0          ok   FR  Female
# 3               0.0            0.0      0.0          ok   FR    Male
# 4               0.0            0.0      0.0          ok   FR  Female
#
#      post_town   age             education employment_status  \
# 0    Prienų r.  21.0  Vocational education          Employed
# 1  Joniškio r.  25.0  Vocational education          Employed
# 2      Vilnius  41.0              Graduate          Employed
# 3      Vilnius  26.0           High school          Employed
# 4    Panevėžys  33.0         Post graduate          Employed
#
#                              occupation employ_how_long  \
# 0        Rušiuotojas / Sorting operator               6
# 1                 Mechanikas / Mechanic               3
# 2                 Vadybininkė / Manager              60
# 3                  Vairuotojas / Driver              36
# 4  Socialinė darbuotoja / Social worker              15
#
#   years_working_in_total  dependants marital_status    credit_check_date  \
# 0                      3           0         Single  2019-09-04 00:00:00
# 1                      4           0         Single  2019-09-04 00:00:00
# 2                      6           1        Married  2019-09-04 00:00:00
# 3                      7           1        Married  2019-09-04 00:00:00
# 4                      3           2        Married  2019-09-04 00:00:00
#
#    monthly_income  monthly_expenses  available_income     dti  \
# 0           503.0                 0             503.0  0.2995
# 1           345.0                17             328.0  0.3003
# 2          1060.0               197             863.0  0.2460
# 3           484.0                 0             484.0  0.1989
# 4           849.0                21             828.0  0.1941
#
#    outstanding_debts       last_debt_date
# 0                  0                    -
# 1                  0  2018-01-04 00:00:00
# 2                  0  2016-11-30 00:00:00
# 3                  0                    -
# 4                  0                    -

# %%
df[features].select_dtypes(include=['object'])
# Out:
#       gender             education employment_status employ_how_long  \
# 0     Female  Vocational education          Employed               6
# 1       Male  Vocational education          Employed               3
# 2     Female              Graduate          Employed              60
# 3       Male           High school          Employed              36
# 4     Female         Post graduate          Employed              15
# ...      ...                   ...               ...             ...
# 9009  Female              Graduate          Employed      72 or more
# 9010  Female         Post graduate          Employed              48
# 9011    Male         Post graduate          Employed               9
# 9012  Female         Post graduate          Employed              60
# 9013  Female              Graduate          Employed              18
#
#      years_working_in_total marital_status
# 0                         3         Single
# 1                         4         Single
# 2                         6        Married
# 3                         7        Married
# 4                         3        Married
# ...                     ...            ...
# 9009                     12        Married
# 9010                      8         Single
# 9011                      2         Single
# 9012                     10         Single
# 9013                      8         Single
#
# [8989 rows x 6 columns]

# %% [markdown]
# ## Comments to finbee.lt
# 1. Would be nice to have more recent data
# 2. Some data is definitely collected wrongly (years_working_in_total)
# 3. monthly_expenses - More than 50% have lower than 100EUR/month - very suspicious
# 4. outstanding_debts - most are 0, no data is collected
